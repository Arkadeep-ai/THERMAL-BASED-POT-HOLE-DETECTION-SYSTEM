# %% [markdown]
# <a href="https://colab.research.google.com/github/Arkadeep-ai/THERMAL-BASED-POT-HOLE-DETECTION-SYSTEM/blob/main/AI_TRAINING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ROOT_DIR = '/content/gdrive/MyDrive/YOLO/data'

# %%
pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (8.4.19)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.10.0+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.25.0+cpu)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)

# %%
import os
from ultralytics import YOLO


model = YOLO('yolov8n.yaml')
results = model.train(data=os.path.join(ROOT_DIR, "google_config.yaml"), epochs= 60)
# Out:
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/gdrive/MyDrive/YOLO/data/google_config.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=60, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.yaml, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 26.0MB/s 0.0s
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752287  ultralytics.nn.modules.head.Detect           [5, 16, None, [64, 128, 256]]
# YOLOv8n summary: 130 layers, 3,011,823 parameters, 3,011,807 gradients, 8.2 GFLOPs
#
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 1.4±1.0 ms, read: 0.7±0.3 MB/s, size: 234.6 KB)
# train: Scanning /content/gdrive/MyDrive/YOLO/data/labels... 20 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 20/20 1.3it/s 15.3s
# train: New cache created: /content/gdrive/MyDrive/YOLO/data/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.6±0.3 ms, read: 54.1±13.3 MB/s, size: 196.7 KB)
# val: Scanning /content/gdrive/MyDrive/YOLO/data/labels.cache... 20 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 20/20 4.7Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001111, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /content/runs/detect/train/labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /content/runs/detect/train
# Starting training for 60 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/60         0G      2.667      4.596      4.318         11        640: 100% ━━━━━━━━━━━━ 2/2 12.6s/it 25.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.8s/it 6.8s
#                    all         20         21    0.00336      0.375    0.00342    0.00118
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/60         0G      3.285      4.711      4.271          8        640: 100% ━━━━━━━━━━━━ 2/2 11.3s/it 22.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.2s/it 7.2s
#                    all         20         21     0.0036      0.375    0.00433    0.00141
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/60         0G      3.136      4.615      4.291          8        640: 100% ━━━━━━━━━━━━ 2/2 9.9s/it 19.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.3s/it 8.3s
#                    all         20         21    0.00362      0.375    0.00549    0.00175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/60         0G      2.947      4.397      4.276         16        640: 100% ━━━━━━━━━━━━ 2/2 10.0s/it 19.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.5s/it 7.5s
#                    all         20         21    0.00343      0.375    0.00453    0.00134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/60         0G      2.964      4.541      4.332          9        640: 100% ━━━━━━━━━━━━ 2/2 9.7s/it 19.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.5s/it 6.5s
#                    all         20         21    0.00357      0.375    0.00391    0.00127
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/60         0G      3.199      4.223      4.246         11        640: 100% ━━━━━━━━━━━━ 2/2 10.3s/it 20.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.7s/it 6.7s
#                    all         20         21    0.00354      0.375    0.00419    0.00144
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/60         0G      3.048      4.445      4.322         11        640: 100% ━━━━━━━━━━━━ 2/2 10.3s/it 20.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.7s/it 7.7s
#                    all         20         21    0.00343      0.375    0.00398    0.00126
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/60         0G      2.832      4.446      4.248          8        640: 100% ━━━━━━━━━━━━ 2/2 9.9s/it 19.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.2s/it 8.2s
#                    all         20         21    0.00346      0.375    0.00422    0.00135
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/60         0G       2.91      4.564      4.273          6        640: 100% ━━━━━━━━━━━━ 2/2 10.1s/it 20.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.6s/it 7.6s
#                    all         20         21    0.00365      0.375    0.00387    0.00126
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/60         0G      2.995      4.327      4.238         14        640: 100% ━━━━━━━━━━━━ 2/2 10.0s/it 20.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.7s/it 6.7s
#                    all         20         21    0.00388      0.375    0.00373    0.00115
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/60         0G      3.173      4.198      4.196         11        640: 100% ━━━━━━━━━━━━ 2/2 11.9s/it 23.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.3s/it 6.3s
#                    all         20         21    0.00349      0.375    0.00352    0.00113
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/60         0G      2.702      4.376      4.172          9        640: 100% ━━━━━━━━━━━━ 2/2 10.9s/it 21.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.8s/it 6.8s
#                    all         20         21    0.00356      0.375    0.00378    0.00131
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/60         0G      2.718      4.213      4.194          9        640: 100% ━━━━━━━━━━━━ 2/2 9.7s/it 19.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.1s/it 8.1s
#                    all         20         21    0.00376      0.375    0.00364    0.00122
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/60         0G       3.07      4.256      4.202          9        640: 100% ━━━━━━━━━━━━ 2/2 9.9s/it 19.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.6s/it 7.6s
#                    all         20         21    0.00382      0.375    0.00379     0.0013
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/60         0G       2.96       4.16       4.22         12        640: 100% ━━━━━━━━━━━━ 2/2 9.7s/it 19.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.5s/it 6.5s
#                    all         20         21    0.00362      0.375    0.00349    0.00112
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/60         0G      2.968      4.237      4.222          9        640: 100% ━━━━━━━━━━━━ 2/2 10.5s/it 21.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.8s/it 6.8s
#                    all         20         21    0.00358      0.375    0.00344    0.00118
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/60         0G      3.211      4.371      4.196         13        640: 100% ━━━━━━━━━━━━ 2/2 9.6s/it 19.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.1s/it 8.1s
#                    all         20         21    0.00375      0.375    0.00351    0.00124
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/60         0G      2.775      4.166      4.187         11        640: 100% ━━━━━━━━━━━━ 2/2 9.7s/it 19.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.9s/it 7.9s
#                    all         20         21    0.00363      0.375    0.00355    0.00113
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/60         0G      2.994      4.146       4.16         13        640: 100% ━━━━━━━━━━━━ 2/2 9.6s/it 19.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.4s/it 6.4s
#                    all         20         21    0.00351      0.375    0.00329    0.00105
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/60         0G      2.747      4.267      4.134          8        640: 100% ━━━━━━━━━━━━ 2/2 10.1s/it 20.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.8s/it 6.8s
#                    all         20         21    0.00332      0.375    0.00321    0.00105
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/60         0G      2.882      4.135      4.156         16        640: 100% ━━━━━━━━━━━━ 2/2 9.9s/it 19.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.1s/it 8.1s
#                    all         20         21    0.00326      0.375    0.00303    0.00105
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/60         0G      2.817      4.318      4.128         14        640: 100% ━━━━━━━━━━━━ 2/2 9.7s/it 19.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.0s/it 8.0s
#                    all         20         21    0.00321      0.375    0.00307    0.00103
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/60         0G      2.671      4.133      4.134         10        640: 100% ━━━━━━━━━━━━ 2/2 9.7s/it 19.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.4s/it 6.4s
#                    all         20         21     0.0032      0.375    0.00296   0.000981
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/60         0G      2.938      4.098      4.137         13        640: 100% ━━━━━━━━━━━━ 2/2 10.8s/it 21.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.4s/it 6.4s
#                    all         20         21     0.0032      0.375    0.00297    0.00106
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/60         0G      3.145      4.116      4.146         13        640: 100% ━━━━━━━━━━━━ 2/2 9.6s/it 19.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.0s/it 8.0s
#                    all         20         21     0.0032      0.375    0.00301    0.00103
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/60         0G      2.916      4.154      4.074          8        640: 100% ━━━━━━━━━━━━ 2/2 9.9s/it 19.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.1s/it 8.1s
#                    all         20         21    0.00321      0.375    0.00311    0.00102
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/60         0G       3.08      4.088      4.102          9        640: 100% ━━━━━━━━━━━━ 2/2 9.3s/it 18.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.1s/it 6.1s
#                    all         20         21     0.0038      0.375    0.00395    0.00135
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/60         0G      3.055      4.086      4.095         10        640: 100% ━━━━━━━━━━━━ 2/2 10.0s/it 20.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.9s/it 6.9s
#                    all         20         21     0.0038      0.375    0.00395    0.00135
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/60         0G      2.719      3.898      4.099         10        640: 100% ━━━━━━━━━━━━ 2/2 9.7s/it 19.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.6s/it 8.6s
#                    all         20         21    0.00376      0.375    0.00397     0.0014
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/60         0G      2.989      4.048      4.104         11        640: 100% ━━━━━━━━━━━━ 2/2 10.2s/it 20.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.4s/it 8.4s
#                    all         20         21    0.00334      0.375    0.00389    0.00128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/60         0G        2.9      4.074      4.101         15        640: 100% ━━━━━━━━━━━━ 2/2 10.0s/it 20.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.8s/it 6.8s
#                    all         20         21    0.00334      0.375    0.00389    0.00128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/60         0G      3.472      4.032      4.066          7        640: 100% ━━━━━━━━━━━━ 2/2 9.8s/it 19.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.5s/it 6.5s
#                    all         20         21    0.00327      0.375    0.00442    0.00148
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/60         0G      2.992      4.186      4.084          8        640: 100% ━━━━━━━━━━━━ 2/2 13.2s/it 26.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.6s/it 6.6s
#                    all         20         21    0.00327      0.375    0.00579    0.00192
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/60         0G       2.91      3.925      4.069         10        640: 100% ━━━━━━━━━━━━ 2/2 9.7s/it 19.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.0s/it 8.0s
#                    all         20         21    0.00327      0.375    0.00579    0.00192
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/60         0G      3.009      3.882      4.046         14        640: 100% ━━━━━━━━━━━━ 2/2 9.8s/it 19.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.9s/it 7.9s
#                    all         20         21    0.00304      0.375     0.0066      0.002
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/60         0G      2.565      4.149      3.946          5        640: 100% ━━━━━━━━━━━━ 2/2 10.8s/it 21.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.4s/it 7.4s
#                    all         20         21     0.0032      0.375    0.00644    0.00218
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/60         0G       2.79      3.951      4.069         12        640: 100% ━━━━━━━━━━━━ 2/2 10.2s/it 20.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.2s/it 6.2s
#                    all         20         21     0.0032      0.375    0.00644    0.00218
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/60         0G      2.828       4.19      4.053          6        640: 100% ━━━━━━━━━━━━ 2/2 9.6s/it 19.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.4s/it 7.4s
#                    all         20         21    0.00306      0.375    0.00507    0.00161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/60         0G      2.626      3.783      3.992         12        640: 100% ━━━━━━━━━━━━ 2/2 9.7s/it 19.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.1s/it 8.1s
#                    all         20         21    0.00308      0.375    0.00404    0.00131
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/60         0G      2.864      4.064      4.043         15        640: 100% ━━━━━━━━━━━━ 2/2 9.6s/it 19.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.6s/it 6.6s
#                    all         20         21    0.00308      0.375    0.00404    0.00131
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/60         0G      2.994        3.8      3.983         11        640: 100% ━━━━━━━━━━━━ 2/2 9.8s/it 19.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.6s/it 6.6s
#                    all         20         21    0.00303      0.375     0.0034    0.00108
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/60         0G      2.977      3.931       3.99          8        640: 100% ━━━━━━━━━━━━ 2/2 9.7s/it 19.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.7s/it 7.7s
#                    all         20         21    0.00306      0.375    0.00345    0.00108
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/60         0G      2.779      3.789      3.899          7        640: 100% ━━━━━━━━━━━━ 2/2 9.8s/it 19.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.3s/it 8.3s
#                    all         20         21    0.00306      0.375    0.00345    0.00108
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/60         0G      2.896      3.667      3.993         17        640: 100% ━━━━━━━━━━━━ 2/2 9.8s/it 19.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.7s/it 6.7s
#                    all         20         21     0.0031      0.375     0.0038    0.00123
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/60         0G       2.79      3.774      3.888          9        640: 100% ━━━━━━━━━━━━ 2/2 9.9s/it 19.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.6s/it 6.6s
#                    all         20         21     0.0031      0.375     0.0038    0.00123
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/60         0G      3.016      3.632      3.912         12        640: 100% ━━━━━━━━━━━━ 2/2 9.8s/it 19.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.1s/it 8.1s
#                    all         20         21    0.00304      0.375    0.00609    0.00207
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/60         0G      2.843      3.854       4.02          9        640: 100% ━━━━━━━━━━━━ 2/2 9.6s/it 19.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.4s/it 8.4s
#                    all         20         21    0.00304      0.375    0.00609    0.00207
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/60         0G      2.887      3.917      3.928         12        640: 100% ━━━━━━━━━━━━ 2/2 9.8s/it 19.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.9s/it 6.9s
#                    all         20         21    0.00299      0.375      0.112     0.0427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/60         0G      2.979      3.775      3.927         10        640: 100% ━━━━━━━━━━━━ 2/2 9.9s/it 19.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.8s/it 6.8s
#                    all         20         21    0.00299      0.375      0.112     0.0427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/60         0G       3.04      3.849      3.938         12        640: 100% ━━━━━━━━━━━━ 2/2 10.0s/it 20.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.4s/it 7.4s
#                    all         20         21    0.00458      0.625      0.105     0.0319
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/60         0G      2.404      4.456      3.739          4        640: 100% ━━━━━━━━━━━━ 2/2 9.7s/it 19.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.5s/it 8.5s
#                    all         20         21    0.00458      0.625      0.105     0.0319
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/60         0G      2.282      4.216        3.8          4        640: 100% ━━━━━━━━━━━━ 2/2 9.6s/it 19.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.5s/it 7.5s
#                    all         20         21    0.00447      0.625      0.105     0.0307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/60         0G      2.404      4.237      3.788          4        640: 100% ━━━━━━━━━━━━ 2/2 10.0s/it 19.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.7s/it 6.7s
#                    all         20         21    0.00447      0.625      0.105     0.0307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/60         0G      2.333      4.218      3.771          4        640: 100% ━━━━━━━━━━━━ 2/2 9.7s/it 19.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.4s/it 7.4s
#                    all         20         21    0.00456      0.625     0.0978     0.0263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/60         0G      2.281      4.351      3.764          4        640: 100% ━━━━━━━━━━━━ 2/2 12.3s/it 24.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.5s/it 8.5s
#                    all         20         21    0.00456      0.625     0.0978     0.0263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/60         0G      2.413      4.377      3.774          4        640: 100% ━━━━━━━━━━━━ 2/2 10.0s/it 20.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.4s/it 8.4s
#                    all         20         21    0.00469      0.625     0.0973     0.0234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/60         0G      2.285      4.288      3.684          4        640: 100% ━━━━━━━━━━━━ 2/2 9.7s/it 19.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.1s/it 7.1s
#                    all         20         21    0.00469      0.625     0.0973     0.0234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/60         0G       2.49      4.166      3.722          4        640: 100% ━━━━━━━━━━━━ 2/2 10.0s/it 20.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.6s/it 6.6s
#                    all         20         21    0.00495      0.625      0.095     0.0238
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/60         0G      2.553      4.282      3.786          4        640: 100% ━━━━━━━━━━━━ 2/2 9.8s/it 19.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.9s/it 7.9s
#                    all         20         21    0.00495      0.625      0.095     0.0238
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/60         0G      2.479      4.309      3.595          4        640: 100% ━━━━━━━━━━━━ 2/2 9.6s/it 19.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 8.5s/it 8.5s
#                    all         20         21    0.00525      0.625     0.0934     0.0233
#
# 60 epochs completed in 0.464 hours.
# Optimizer stripped from /content/runs/detect/train/weights/last.pt, 6.3MB
# Optimizer stripped from /content/runs/detect/train/weights/best.pt, 6.3MB
#
# Validating /content/runs/detect/train/weights/best.pt...
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# YOLOv8n summary (fused): 73 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.8s/it 5.8s
#                    all         20         21      0.003      0.375      0.112     0.0427
#         large and deep         12         12    0.00599       0.75      0.223     0.0853
#      large but no deep          9          9          0          0          0          0
# Speed: 2.6ms preprocess, 248.4ms inference, 0.0ms loss, 4.1ms postprocess per image
# Results saved to /content/runs/detect/train

# %%
# !scp -r /content/runs '/content/gdrive/MyDrive/YOLO/data'
